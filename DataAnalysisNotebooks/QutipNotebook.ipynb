# %%
import qutip as qt
from vtk import vtkmodules
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [11], in <cell line: 2>()
#       1 import qutip as qt
# ----> 2 from vtk import vtkmodules
#
# File ~\AppData\Local\Continuum\anaconda3\envs\qutip-env\lib\site-packages\vtk.py:31, in <module>
#      29 import importlib
#      30 # import vtkmodules.all
# ---> 31 all_m = importlib.import_module('vtkmodules.all')
#      33 # import vtkmodules
#      34 vtkmodules_m = importlib.import_module('vtkmodules')
#
# File ~\AppData\Local\Continuum\anaconda3\envs\qutip-env\lib\importlib\__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~\AppData\Local\Continuum\anaconda3\envs\qutip-env\lib\site-packages\vtkmodules\all.py:7, in <module>
#       4 from __future__ import absolute_import
# ...

# %%
b3d = qutip.Bloch3d()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Local\Continuum\anaconda3\envs\qutip-env\lib\site-packages\qutip\bloch3d.py:80, in Bloch3d.__init__(self, fig)
#      79 try:
# ---> 80     from mayavi import mlab
#      81 except:
#
# File ~\AppData\Local\Continuum\anaconda3\envs\qutip-env\lib\site-packages\mayavi\mlab.py:16, in <module>
#      15 from mayavi.core.common import process_ui_events
# ---> 16 from mayavi.tools.camera import view, roll, yaw, pitch, move
#      17 from mayavi.tools.figure import figure, clf, gcf, savefig, \
#      18     draw, sync_camera, close, screenshot
#
# File ~\AppData\Local\Continuum\anaconda3\envs\qutip-env\lib\site-packages\mayavi\tools\camera.py:24, in <module>
#      22 # We can't use gcf, as it creates a circular import in camera management
#      23 # routines.
# ---> 24 from .engine_manager import get_engine
# ...
